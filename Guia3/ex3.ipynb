# %%
import numpy as np 
from tabulate import tabulate                   # Para generar tablas

from sklearn import datasets                    # Módulo para levantar los datos
from sklearn.metrics import accuracy_score      # Medida de precisión
from sklearn.model_selection import KFold       # Modelo de partición

# Clasificadores:
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
def generar_kfold(X_digits, y_digits, clf, n_folds=5):
  kf = KFold(n_splits=5, random_state=42, shuffle=True)
  ACC = []

  for fold, (train_index, test_index) in enumerate(kf.split(X_digits)): 
      X_train, y_train = X_digits[train_index], y_digits[train_index]
      X_test, y_test = X_digits[test_index], y_digits[test_index]
      # Entrenamiento del modelo
      clf.fit(X_train, y_train)
      y_pred = clf.predict(X_test)
      acc_fold = accuracy_score(y_test, y_pred)
      ACC.append(acc_fold)

  return ACC

# %%
X_wines, y_wines = datasets.load_wine(return_X_y=True)
list(wine.target_names)
ACC_mean = []

# %% [markdown]
# # Bagging

# %%
# Árbol de decisión con profundidad máxima 1
base_clf = DecisionTreeClassifier(max_depth=1)
# Tendremos 50 modelos 
clf = BaggingClassifier(base_clf,n_estimators=50)
ACC = generar_kfold(X_wines, y_wines, clf)
print(f"% de aciertos medios: {np.mean(ACC)}")
print(f"Varianza de la exactitud: {np.var(ACC)}")
ACC_mean.append(("Bagging (Arbol de decision: Prof. Max = 1)", np.mean(ACC)))
# Out:
# % de aciertos medios: 0.8649206349206349
# Varianza de la exactitud: 0.0008176870748299303

# %%
# Árbol de decisión con profundidad máxima 1
base_clf = DecisionTreeClassifier(max_depth=3)
# Tendremos 50 modelos 
clf = BaggingClassifier(base_clf,n_estimators=50)
ACC = generar_kfold(X_wines, y_wines, clf)
print(f"% de aciertos medios: {np.mean(ACC)}")
print(f"Varianza de la exactitud: {np.var(ACC)}")
ACC_mean.append(("Bagging (Arbol de decision: Prof. Max = 3)", np.mean(ACC)))
# Out:
# % de aciertos medios: 0.971904761904762
# Varianza de la exactitud: 0.0006353237591332835

# %%
# Árbol de decisión con profundidad máxima 1
base_clf = DecisionTreeClassifier(max_depth=1)
# Tendremos 50 modelos 
clf = BaggingClassifier(base_clf,n_estimators=50)
ACC = generar_kfold(X_wines, y_wines, clf)
print(f"% de aciertos medios: {np.mean(ACC)}")
print(f"Varianza de la exactitud: {np.var(ACC)}")
ACC_mean.append(("Bagging (Arbol de decision: Prof. Max = 5)", np.mean(ACC)))
# Out:
# % de aciertos medios: 0.8817460317460316
# Varianza de la exactitud: 0.001141597379692615

# %% [markdown]
# # AdaBoost

# %%
# Árbol de decisión con profundidad máxima 1
base_clf = DecisionTreeClassifier(max_depth=1)
# Tendremos 50 modelos 
clf = AdaBoostClassifier(base_clf,n_estimators=50)
ACC = generar_kfold(X_wines, y_wines, clf)
print(f"% de aciertos medios: {np.mean(ACC)}")
print(f"Varianza de la exactitud: {np.var(ACC)}")
ACC_mean.append(("AdaBoost (Arbol de decision: Prof. Max = 1)", np.mean(ACC)))
# Out:
# % de aciertos medios: 0.9495238095238095
# Varianza de la exactitud: 0.00042897455278407697

# %%
# Árbol de decisión con profundidad máxima 1
base_clf = DecisionTreeClassifier(max_depth=3)
# Tendremos 50 modelos 
clf = AdaBoostClassifier(base_clf,n_estimators=50)
ACC = generar_kfold(X_wines, y_wines, clf)
print(f"% de aciertos medios: {np.mean(ACC)}")
print(f"Varianza de la exactitud: {np.var(ACC)}")
ACC_mean.append(("AdaBoost (Arbol de decision: Prof. Max = 3)", np.mean(ACC)))
# Out:
# % de aciertos medios: 0.9492063492063492
# Varianza de la exactitud: 0.0017387251196775018

# %%
# Árbol de decisión con profundidad máxima 1
base_clf = DecisionTreeClassifier(max_depth=5)
# Tendremos 50 modelos 
clf = AdaBoostClassifier(base_clf,n_estimators=50)
ACC = generar_kfold(X_wines, y_wines, clf)
print(f"% de aciertos medios: {np.mean(ACC)}")
print(f"Varianza de la exactitud: {np.var(ACC)}")
ACC_mean.append(("AdaBoost (Arbol de decision: Prof. Max = 5)", np.mean(ACC)))
# Out:
# % de aciertos medios: 0.8876190476190476
# Varianza de la exactitud: 0.001563517258755353

# %%
# Creamos una tabla
ACC_mean = sorted(ACC_mean, key=lambda x: x[1], reverse=True)

table_data = []
for nombre, acc in ACC_mean:
    table_data.append({"Método": nombre, "Accuracy": acc})

table = tabulate(table_data, headers="keys", tablefmt="simple_grid", stralign="center", numalign='center')
print(table)
# Out:
# ┌─────────────────────────────────────────────┬────────────┐
# │                   Método                    │  Accuracy  │
# ├─────────────────────────────────────────────┼────────────┤
# │ Bagging (Arbol de decision: Prof. Max = 3)  │  0.971905  │
# ├─────────────────────────────────────────────┼────────────┤
# │ AdaBoost (Arbol de decision: Prof. Max = 1) │  0.949524  │
# ├─────────────────────────────────────────────┼────────────┤
# │ AdaBoost (Arbol de decision: Prof. Max = 3) │  0.949206  │
# ├─────────────────────────────────────────────┼────────────┤
# │ AdaBoost (Arbol de decision: Prof. Max = 5) │  0.887619  │
# ├─────────────────────────────────────────────┼────────────┤
# │ Bagging (Arbol de decision: Prof. Max = 5)  │  0.881746  │
# ├─────────────────────────────────────────────┼────────────┤
# │ Bagging (Arbol de decision: Prof. Max = 1)  │  0.864921  │
# └─────────────────────────────────────────────┴────────────┘
